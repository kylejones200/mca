# %% [markdown]
# # Multiple Correspondence Analysis with Central Asian Countries and Organizations
#
# by Kyle Jones, D.ENG.
#
# December 20, 2018
#
# Uses the MCA technique to identify similarities in multilateral diplomacy of Central Asian countries based on their participation in political economic organizations.

# %%
import numpy as np
import pandas as pd
import mca

# %%
df = pd.read_excel('correspond.xlsx', skiprows=0, index_col=0, header=0)

# %%
df = pd.DataFrame.transpose(df)

# %%
df
# Out:
# Country                                             Afghanistan  Armenia  \
# OSCE                                                          0        1
# Eurasian Economic Union                                       0        1
# Eurasian customs union                                        0        1
# Commonwealth of Independent States Free Trade Area            0        1
# Shainghai Cooperation Organizatin                             0        0
# Collective Security Treaty Organization                       0        1
# parternship for peace                                         0        1
# Asia-Pacific Economic Cooperation                             0        0
# Eurasian Economic Union.1                                     0        1
# Individual action plan (NATO)                                 0        1
# commonwealth of indipendent states                            0        1
# Economic Cooperation Organization                             1        0
#
# Country                                             Australia  Azerbaijan  \
# OSCE                                                        0           1
# Eurasian Economic Union                                     0           0
# Eurasian customs union                                      0           0
# Commonwealth of Independent States Free Trade Area          0           1
# Shainghai Cooperation Organizatin                           0           0
# Collective Security Treaty Organization                     0           0
# parternship for peace                                       0           1
# Asia-Pacific Economic Cooperation                           1           0
# Eurasian Economic Union.1                                   0           0
# Individual action plan (NATO)                               0           1
# commonwealth of indipendent states                          0           1
# Economic Cooperation Organization                           0           1
#
# Country                                             Belarus  Bosnia  China  \
# OSCE                                                      1       1      0
# Eurasian Economic Union                                   1       0      0
# Eurasian customs union                                    1       0      0
# Commonwealth of Independent States Free Trade Area        1       0      0
# Shainghai Cooperation Organizatin                         0       0      1
# Collective Security Treaty Organization                   1       0      0
# parternship for peace                                     1       0      0
# Asia-Pacific Economic Cooperation                         0       0      1
# Eurasian Economic Union.1                                 1       0      0
# Individual action plan (NATO)                             0       1      0
# commonwealth of indipendent states                        1       0      0
# Economic Cooperation Organization                         0       0      0
#
# Country                                             Georgia  Kazakhstan  \
# OSCE                                                      1           1
# Eurasian Economic Union                                   0           1
# Eurasian customs union                                    0           1
# Commonwealth of Independent States Free Trade Area        0           1
# Shainghai Cooperation Organizatin                         0           1
# Collective Security Treaty Organization                   0           1
# parternship for peace                                     1           0
# Asia-Pacific Economic Cooperation                         0           0
# Eurasian Economic Union.1                                 0           1
# Individual action plan (NATO)                             1           1
# commonwealth of indipendent states                        0           1
# Economic Cooperation Organization                         0           1
#
# Country                                             Kyrgyzstan   ...     \
# OSCE                                                         1   ...
# Eurasian Economic Union                                      1   ...
# Eurasian customs union                                       1   ...
# Commonwealth of Independent States Free Trade Area           1   ...
# Shainghai Cooperation Organizatin                            1   ...
# Collective Security Treaty Organization                      1   ...
# parternship for peace                                        0   ...
# Asia-Pacific Economic Cooperation                            0   ...
# Eurasian Economic Union.1                                    1   ...
# Individual action plan (NATO)                                0   ...
# commonwealth of indipendent states                           1   ...
# Economic Cooperation Organization                            1   ...
#
# Country                                             Pakistan  Russia  Serbia  \
# OSCE                                                       0       1       1
# Eurasian Economic Union                                    0       1       0
# Eurasian customs union                                     0       1       0
# Commonwealth of Independent States Free Trade Area         0       1       0
# Shainghai Cooperation Organizatin                          1       1       0
# Collective Security Treaty Organization                    0       1       1
# parternship for peace                                      0       1       0
# Asia-Pacific Economic Cooperation                          0       1       0
# Eurasian Economic Union.1                                  0       1       0
# Individual action plan (NATO)                              0       0       1
# commonwealth of indipendent states                         0       1       0
# Economic Cooperation Organization                          1       0       0
#
# Country                                             Tajikistan  \
# OSCE                                                         1
# Eurasian Economic Union                                      0
# Eurasian customs union                                       0
# Commonwealth of Independent States Free Trade Area           1
# Shainghai Cooperation Organizatin                            1
# Collective Security Treaty Organization                      1
# parternship for peace                                        1
# Asia-Pacific Economic Cooperation                            0
# Eurasian Economic Union.1                                    0
# Individual action plan (NATO)                                0
# commonwealth of indipendent states                           1
# Economic Cooperation Organization                            1
#
# Country                                             ThePhilippines  \
# OSCE                                                             0
# Eurasian Economic Union                                          0
# Eurasian customs union                                           0
# Commonwealth of Independent States Free Trade Area               0
# Shainghai Cooperation Organizatin                                0
# Collective Security Treaty Organization                          0
# parternship for peace                                            0
# Asia-Pacific Economic Cooperation                                1
# Eurasian Economic Union.1                                        0
# Individual action plan (NATO)                                    0
# commonwealth of indipendent states                               0
# Economic Cooperation Organization                                0
#
# Country                                             UnitedStates  \
# OSCE                                                           1
# Eurasian Economic Union                                        0
# Eurasian customs union                                         0
# Commonwealth of Independent States Free Trade Area             0
# Shainghai Cooperation Organizatin                              0
# Collective Security Treaty Organization                        0
# parternship for peace                                          0
# Asia-Pacific Economic Cooperation                              1
# Eurasian Economic Union.1                                      0
# Individual action plan (NATO)                                  0
# commonwealth of indipendent states                             0
# Economic Cooperation Organization                              0
#
# Country                                             Turkmenistan   Ukraine  \
# OSCE                                                            1        1
# Eurasian Economic Union                                         0        0
# Eurasian customs union                                          0        0
# Commonwealth of Independent States Free Trade Area              0        1
# Shainghai Cooperation Organizatin                               0        0
# Collective Security Treaty Organization                         0        0
# parternship for peace                                           1        1
# Asia-Pacific Economic Cooperation                               0        0
# Eurasian Economic Union.1                                       0        0
# Individual action plan (NATO)                                   0        0
# commonwealth of indipendent states                              0        0
# Economic Cooperation Organization                               1        0
#
# Country                                             Uzbekistan  Vietnam
# OSCE                                                         1        0
# Eurasian Economic Union                                      0        0
# Eurasian customs union                                       0        0
# Commonwealth of Independent States Free Trade Area           1        0
# Shainghai Cooperation Organizatin                            1        0
# Collective Security Treaty Organization                      0        0
# parternship for peace                                        1        0
# Asia-Pacific Economic Cooperation                            0        1
# Eurasian Economic Union.1                                    0        0
# Individual action plan (NATO)                                0        0
# commonwealth of indipendent states                           1        0
# Economic Cooperation Organization                            1        0
#
# [12 rows x 21 columns]

# %%
x_dummy = mca.dummy(df)
mca_ben = mca.MCA(x_dummy)

# %%
src_index = (['OSCE']*2 +
['Eurasian Economic Union']*2 +
['Eurasian customs union']*2 +
['Commonwealth of Independent States Free Trade Area']*2+ 
['Shainghai Cooperation Organizatin']*2+
['Collective Security Treaty Organization']*2+
['parternship for peace']*2+
['Asia-Pacific Economic Cooperation']*2+
['Eurasian Economic Union.1']*2+
['Individual action plan (NATO)']*2+
['commonwealth of indipendent states']*2+
['Economic Cooperation Organization']*2
            )

# %%
yn = ['y','n']; val_index = yn*len(df.columns)
col_index = pd.MultiIndex.from_arrays([src_index, val_index], 
                                      names=['source', 'value'])

# %%
table1 = pd.DataFrame(data=x_dummy.values, index=x_dummy.index, columns=col_index)

# %%
table1
# Out:
# source         OSCE    Eurasian Economic Union    Eurasian customs union     \
# value             y  n                       y  n                      y  n
# Country
# Afghanistan       1  0                       1  0                      1  0
# Armenia           0  1                       0  1                      0  1
# Australia         1  0                       1  0                      1  0
# Azerbaijan        0  1                       1  0                      1  0
# Belarus           0  1                       0  1                      0  1
# Bosnia            0  1                       1  0                      1  0
# China             1  0                       1  0                      1  0
# Georgia           0  1                       1  0                      1  0
# Kazakhstan        0  1                       0  1                      0  1
# Kyrgyzstan        0  1                       0  1                      0  1
# Moldova           0  1                       1  0                      1  0
# Pakistan          1  0                       1  0                      1  0
# Russia            0  1                       0  1                      0  1
# Serbia            0  1                       1  0                      1  0
# Tajikistan        0  1                       1  0                      1  0
# ThePhilippines    1  0                       1  0                      1  0
# UnitedStates      0  1                       1  0                      1  0
# Turkmenistan      0  1                       1  0                      1  0
# Ukraine           0  1                       1  0                      1  0
# Uzbekistan        0  1                       1  0                      1  0
# Vietnam           1  0                       1  0                      1  0
#
# source         Commonwealth of Independent States Free Trade Area     \
# value                                                           y  n
# Country
# Afghanistan                                                     1  0
# Armenia                                                         0  1
# Australia                                                       1  0
# Azerbaijan                                                      0  1
# Belarus                                                         0  1
# Bosnia                                                          1  0
# China                                                           1  0
# Georgia                                                         1  0
# Kazakhstan                                                      0  1
# Kyrgyzstan                                                      0  1
# Moldova                                                         0  1
# Pakistan                                                        1  0
# Russia                                                          0  1
# Serbia                                                          1  0
# Tajikistan                                                      0  1
# ThePhilippines                                                  1  0
# UnitedStates                                                    1  0
# Turkmenistan                                                    1  0
# Ukraine                                                         0  1
# Uzbekistan                                                      0  1
# Vietnam                                                         1  0
#
# source         Shainghai Cooperation Organizatin    ...  \
# value                                          y  n ...
# Country                                             ...
# Afghanistan                                    1  0 ...
# Armenia                                        1  0 ...
# Australia                                      1  0 ...
# Azerbaijan                                     1  0 ...
# Belarus                                        1  0 ...
# Bosnia                                         1  0 ...
# China                                          0  1 ...
# Georgia                                        1  0 ...
# Kazakhstan                                     0  1 ...
# Kyrgyzstan                                     0  1 ...
# Moldova                                        1  0 ...
# Pakistan                                       0  1 ...
# Russia                                         0  1 ...
# Serbia                                         1  0 ...
# Tajikistan                                     0  1 ...
# ThePhilippines                                 1  0 ...
# UnitedStates                                   1  0 ...
# Turkmenistan                                   1  0 ...
# Ukraine                                        1  0 ...
# Uzbekistan                                     0  1 ...
# Vietnam                                        1  0 ...
#
# source         Asia-Pacific Economic Cooperation    Eurasian Economic Union.1  \
# value                                          y  n                         y
# Country
# Afghanistan                                    1  0                         1
# Armenia                                        1  0                         0
# Australia                                      0  1                         1
# Azerbaijan                                     1  0                         1
# Belarus                                        1  0                         0
# Bosnia                                         1  0                         1
# China                                          0  1                         1
# Georgia                                        1  0                         1
# Kazakhstan                                     1  0                         0
# Kyrgyzstan                                     1  0                         0
# Moldova                                        1  0                         1
# Pakistan                                       1  0                         1
# Russia                                         0  1                         0
# Serbia                                         1  0                         1
# Tajikistan                                     1  0                         1
# ThePhilippines                                 0  1                         1
# UnitedStates                                   0  1                         1
# Turkmenistan                                   1  0                         1
# Ukraine                                        1  0                         1
# Uzbekistan                                     1  0                         1
# Vietnam                                        0  1                         1
#
# source            Individual action plan (NATO)     \
# value           n                             y  n
# Country
# Afghanistan     0                             1  0
# Armenia         1                             0  1
# Australia       0                             1  0
# Azerbaijan      0                             0  1
# Belarus         1                             1  0
# Bosnia          0                             0  1
# China           0                             1  0
# Georgia         0                             0  1
# Kazakhstan      1                             0  1
# Kyrgyzstan      1                             1  0
# Moldova         0                             0  1
# Pakistan        0                             1  0
# Russia          1                             1  0
# Serbia          0                             0  1
# Tajikistan      0                             1  0
# ThePhilippines  0                             1  0
# UnitedStates    0                             1  0
# Turkmenistan    0                             1  0
# Ukraine         0                             1  0
# Uzbekistan      0                             1  0
# Vietnam         0                             1  0
#
# source         commonwealth of indipendent states     \
# value                                           y  n
# Country
# Afghanistan                                     1  0
# Armenia                                         0  1
# Australia                                       1  0
# Azerbaijan                                      0  1
# Belarus                                         0  1
# Bosnia                                          1  0
# China                                           1  0
# Georgia                                         1  0
# Kazakhstan                                      0  1
# Kyrgyzstan                                      0  1
# Moldova                                         0  1
# Pakistan                                        1  0
# Russia                                          0  1
# Serbia                                          1  0
# Tajikistan                                      0  1
# ThePhilippines                                  1  0
# UnitedStates                                    1  0
# Turkmenistan                                    1  0
# Ukraine                                         1  0
# Uzbekistan                                      0  1
# Vietnam                                         1  0
#
# source         Economic Cooperation Organization
# value                                          y  n
# Country
# Afghanistan                                    0  1
# Armenia                                        1  0
# Australia                                      1  0
# Azerbaijan                                     0  1
# Belarus                                        1  0
# Bosnia                                         1  0
# China                                          1  0
# Georgia                                        1  0
# Kazakhstan                                     0  1
# Kyrgyzstan                                     0  1
# Moldova                                        1  0
# Pakistan                                       0  1
# Russia                                         1  0
# Serbia                                         1  0
# Tajikistan                                     0  1
# ThePhilippines                                 1  0
# UnitedStates                                   1  0
# Turkmenistan                                   0  1
# Ukraine                                        1  0
# Uzbekistan                                     0  1
# Vietnam                                        1  0
#
# [21 rows x 24 columns]

# %%
mca_ben

# %%
ncols = len(x_dummy)
mca_ben = mca.MCA(x_dummy, ncols=ncols)
mca_ind = mca.MCA(x_dummy, ncols=ncols, benzecri=False)

print(mca.MCA.__doc__)
# Out:
# Run MCA on selected columns of a pd DataFrame.
#
# 	If the column are specified, assume that they hold
# 	categorical variables that need to be replaced with
# 	dummy indicators, otherwise process the DataFrame as is.
#
# 	'cols': The columns of the DataFrame to process.
# 	'ncols': The number of columns before dummy coding. To be passed if cols isn't.
# 	'benzecri': Perform Benzécri correction (default: True)
# 	'TOL': value below which to round eigenvalues to zero (default: 1e-4)

# %%
data = {'Zλ': pd.Series(mca_ben.L),
        'τZ': mca_ben.expl_var(greenacre=False, N=4)}

# 'Indicator Matrix', 'Benzecri Correction', 'Greenacre Correction'
columns = ['Zλ', 'τZ']
table2 = pd.DataFrame(data=data, columns=columns).fillna(0)
table2.index += 1
table2.loc['Σ'] = table2.sum()
table2.index.name = 'Factor'

table2
# Out:
#               Zλ        τZ
# Factor
# 1       0.055584  0.622079
# 2       0.019070  0.213429
# 3       0.012849  0.143807
# 4       0.001848  0.020686
# Σ       0.089351  1.000000

# %%
data = np.array([mca_ben.L[:2], 
                 mca_ben.expl_var(greenacre=True, N=2) * 100]).T
df = pd.DataFrame(data=data, columns=['cλ','%c'], index=range(1,3))
df
# Out:
#          cλ          %c
# 1  0.055584 -320.257969
# 2  0.019070 -109.877281

# %%
fs, cos, cont = 'Factor score','Squared cosines', 'Contributions x 1000'
table3 = pd.DataFrame(columns=x_dummy.index, index=pd.MultiIndex
                      .from_product([[fs, cos, cont], range(1, 3)]))

table3.loc[fs,    :] = mca_ben.fs_r(N=2).T
table3.loc[cos,   :] = mca_ben.cos_r(N=2).T
table3.loc[cont,  :] = mca_ben.cont_r(N=2).T * 1000

np.round(table3.astype(float), 2)
# Out:
#                           OSCE  Eurasian Economic Union  \
# Factor score         1    0.28                    -0.03
#                      2    0.22                    -0.14
# Squared cosines      1    0.63                     0.04
#                      2    0.37                     0.64
# Contributions x 1000 1  119.04                     1.73
#                      2  205.89                    80.05
#
#                         Eurasian customs union  \
# Factor score         1                   -0.03
#                      2                   -0.14
# Squared cosines      1                    0.04
#                      2                    0.64
# Contributions x 1000 1                    1.73
#                      2                   80.05
#
#                         Commonwealth of Independent States Free Trade Area  \
# Factor score         1                                               0.18
#                      2                                              -0.00
# Squared cosines      1                                               0.91
#                      2                                               0.00
# Contributions x 1000 1                                              47.12
#                      2                                               0.07
#
#                         Shainghai Cooperation Organizatin  \
# Factor score         1                              -0.16
#                      2                              -0.12
# Squared cosines      1                               0.41
#                      2                               0.24
# Contributions x 1000 1                              36.13
#                      2                              61.92
#
#                         Collective Security Treaty Organization  \
# Factor score         1                                     0.03
#                      2                                    -0.10
# Squared cosines      1                                     0.06
#                      2                                     0.59
# Contributions x 1000 1                                     1.62
#                      2                                    47.36
#
#                         parternship for peace  \
# Factor score         1                   0.18
#                      2                   0.19
# Squared cosines      1                   0.44
#                      2                   0.52
# Contributions x 1000 1                  46.33
#                      2                 161.04
#
#                         Asia-Pacific Economic Cooperation  \
# Factor score         1                              -0.68
#                      2                               0.19
# Squared cosines      1                               0.92
#                      2                               0.07
# Contributions x 1000 1                             697.66
#                      2                             163.57
#
#                         Eurasian Economic Union.1  \
# Factor score         1                      -0.03
#                      2                      -0.14
# Squared cosines      1                       0.04
#                      2                       0.64
# Contributions x 1000 1                       1.73
#                      2                      80.05
#
#                         Individual action plan (NATO)  \
# Factor score         1                           0.11
#                      2                           0.14
# Squared cosines      1                           0.27
#                      2                           0.43
# Contributions x 1000 1                          19.75
#                      2                          90.66
#
#                         commonwealth of indipendent states  \
# Factor score         1                                0.13
#                      2                               -0.04
# Squared cosines      1                                0.84
#                      2                                0.10
# Contributions x 1000 1                               26.29
#                      2                                8.77
#
#                         Economic Cooperation Organization
# Factor score         1                               0.02
#                      2                              -0.07
# Squared cosines      1                               0.01
#                      2                               0.05
# Contributions x 1000 1                               0.88
#                      2                              20.58

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

points = table3.loc[fs].values
labels = table3.columns.values

plt.figure()
plt.margins(0.1)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.xlabel('Factor 1')
plt.ylabel('Factor 2')
plt.scatter(*points, s=120, marker='o', c='r', alpha=.5, linewidths=0)
for label, x, y in zip(labels, *points):
    plt.annotate(label, xy=(x, y), xytext=(x + .03, y + .03))
plt.show()
